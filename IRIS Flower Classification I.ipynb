# %%
# Load the Iris Dataset
# Link : https://www.kaggle.com/datasets/saurabh00007/iriscsv?resource=download

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
iris = pd.read_csv('Downloads/Iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# Preprocess the Data

print(iris.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print(iris.Species)
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
print(iris['Species'].unique())
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
# Descriptive Statistics of the DataFrame

print(iris.describe())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris['Species'] == 'Iris-setosa'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: Species, Length: 150, dtype: bool

# %%
setosa = iris[iris['Species'] == 'Iris-setosa']
setosa
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
# Inspect the Data.

setosa = iris[iris['Species'] == 'Iris-setosa']
versicolor = iris[iris['Species'] == 'Iris-versicolor']
virginica = iris[iris['Species'] == 'Iris-virginica']

plt.scatter(setosa['SepalLengthCm'], setosa['SepalWidthCm'], label='Iris-setosa', marker='o', color='blue')
plt.scatter(versicolor['SepalLengthCm'], versicolor['SepalWidthCm'], label='Iris-versicolor', marker='^', color='green')
plt.scatter(virginica['SepalLengthCm'], virginica['SepalWidthCm'], label='Iris-virginica', marker='s', color='red')

plt.xlabel("SepalLength(CM)")
plt.ylabel("Sepal Width(CM)")
plt.title("SepalLength vs SepalWidth")
plt.legend()
plt.show()

# %%
# Split the Data into Training & Testing Sets.

from sklearn.model_selection import train_test_split
IRIS = iris.drop(['Id',"Species"],axis=1)
iris_feature = np.array(IRIS)
iris_label = np.array(iris['Species'])
x_train,x_test,y_train,y_test = train_test_split(iris_feature, iris_label, random_state=10,test_size=0.2)

# %%
x_train
# Out:
# array([[6.6, 2.9, 4.6, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [7.2, 3. , 5.8, 1.6],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.3, 2.5, 5. , 1.9],
#        [4.6, 3.2, 1.4, 0.2],
#        [6.7, 3.3, 5.7, 2.1],
#        [6.9, 3.2, 5.7, 2.3],
#        [7.7, 2.6, 6.9, 2.3],
#        [6.9, 3.1, 5.1, 2.3],
#        [5. , 3.4, 1.6, 0.4],
#        [5. , 3.5, 1.6, 0.6],
#        [5.2, 2.7, 3.9, 1.4],
#        [4.5, 2.3, 1.3, 0.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [5.2, 4.1, 1.5, 0.1],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.9, 3.2, 4.8, 1.8],
#        [5.6, 2.8, 4.9, 2. ],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.2, 2.2, 4.5, 1.5],
#        [7.2, 3.6, 6.1, 2.5],
#        [5.5, 2.4, 3.7, 1. ],
#        [6. , 2.9, 4.5, 1.5],
#        [6.4, 3.2, 4.5, 1.5],
#        [5.8, 4. , 1.2, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.4, 3.4, 1.7, 0.2],
#        [6.4, 3.1, 5.5, 1.8],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
# ...

# %%
y_train
# Out:
# array(['Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa',
# ...

# %%
# Train the Model using KNN

from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier(n_neighbors=1)
KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
x_test
# Out:
# array([[6.3, 2.3, 4.4, 1.3],
#        [6.4, 2.7, 5.3, 1.9],
#        [5.4, 3.7, 1.5, 0.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5. , 3.3, 1.4, 0.2],
#        [5. , 2. , 3.5, 1. ],
#        [6.3, 2.5, 4.9, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [5.1, 3.4, 1.5, 0.2],
#        [5.7, 2.8, 4.5, 1.3],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [5.5, 2.3, 4. , 1.3],
#        [4.9, 3. , 1.4, 0.2],
#        [5.1, 3.8, 1.5, 0.3],
#        [6.8, 3. , 5.5, 2.1],
#        [6. , 3.4, 4.5, 1.6],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [5. , 3.2, 1.2, 0.2],
#        [7.1, 3. , 5.9, 2.1],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.2, 2.8, 4.8, 1.8],
#        [4.8, 3.4, 1.9, 0.2],
#        [5.9, 3. , 4.2, 1.5],
#        [4.7, 3.2, 1.3, 0.2],
#        [5.7, 3. , 4.2, 1.2],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.8, 2.8, 4.8, 1.4],
#        [7.7, 3.8, 6.7, 2.2]])

# %%
y_test
# Out:
# array(['Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica'],
#       dtype=object)

# %%
IRIS.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')

# %%
# Make Predictions

import numpy as np

new_data = np.array([[6.4,2.7,5.3,1.9]])
new_data_DF = pd.DataFrame(new_data, columns=IRIS.columns)
new_data_DF
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            6.4           2.7            5.3           1.9

# %%
import warnings

# Ignore FutureWarnings during execution
warnings.filterwarnings("ignore", category=FutureWarning)

predictions = KNN.predict(new_data)
"Prediction: {}".format(predictions[0])
# Out:
# 'Prediction: Iris-virginica'

# %%
y_pred = KNN.predict(x_test)
pred_DF = pd.DataFrame(x_test,columns=IRIS.columns)
pred_DF['Predicted Species'] = y_pred
pred_DF
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Predicted Species
# 0             6.3           2.3            4.4           1.3   Iris-versicolor
# 1             6.4           2.7            5.3           1.9    Iris-virginica
# 2             5.4           3.7            1.5           0.2       Iris-setosa
# 3             6.1           3.0            4.6           1.4   Iris-versicolor
# 4             5.0           3.3            1.4           0.2       Iris-setosa
# 5             5.0           2.0            3.5           1.0   Iris-versicolor
# 6             6.3           2.5            4.9           1.5    Iris-virginica
# 7             5.8           2.7            4.1           1.0   Iris-versicolor
# 8             5.1           3.4            1.5           0.2       Iris-setosa
# 9             5.7           2.8            4.5           1.3   Iris-versicolor
# 10            5.6           3.0            4.5           1.5   Iris-versicolor
# ...
